# %% [markdown]
# ### 1. Install required libraries

# %%
# !pip install pdfplumber
# !plip install chromadb
# !pip install tiktoken
# !pip install openai
# !pip install sentence-transformers
# Out:
# ...
#   Obtaining dependency information for pdfplumber from https://files.pythonhosted.org/packages/db/e0/52b67d4f00e09e497aec4f71bc44d395605e8ebcea52543242ed34c25ef9/pdfplumber-0.11.7-py3-none-any.whl.metadata
# ...
#      ---------------------------------------- 0.0/42.8 kB ? eta -:--:--
#      ---------------------------------------- 0.0/42.8 kB ? eta -:--:--
#      ---------------------------------------- 0.0/42.8 kB ? eta -:--:--
#      --------- ------------------------------ 10.2/42.8 kB ? eta -:--:--
#      ------------------ ------------------- 20.5/42.8 kB 640.0 kB/s eta 0:00:01
#      ------------------ ------------------- 20.5/42.8 kB 640.0 kB/s eta 0:00:01
#      ------------------------------------ - 41.0/42.8 kB 245.8 kB/s eta 0:00:01
#      ------------------------------------ - 41.0/42.8 kB 245.8 kB/s eta 0:00:01
#      -------------------------------------- 42.8/42.8 kB 130.1 kB/s eta 0:00:00
# ...
